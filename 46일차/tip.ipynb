# %% [markdown]
# 0. IDE 를 적극적으로 활용해라
# - input.in 써서, 복사하지 말고 사용
# - 디버깅 툴 -> 적극적으로 써라
#     -> print 로 다 디버깅 해야함
#     -> 적재적소에 print 를 사용할 줄 알아야 함
#     -> 디버깅 툴을 활용해서 연습
#
# 1. 문제를 봤을 때, 원하는 알고리즘을 선택
# 1.1. 일단 완전 탐색으로 생각해봐라
# -> N 값을 반드시 확인해서, 시간복잡도 확인
# 1.2. Backtracking 하는 방법 생각
# 1.3. 조금 더 어려운 알고리즘
#     - 그리디 (규칙 찾기)
#     - DP (두 번 계산하지 않기)
#     - Union-Find
