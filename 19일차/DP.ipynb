# %% [markdown]
# # DP
# - 동적 계획 알고리즘은 그리디 알고리즘과 같이 최적화 문제를 해결하는 알고리즘이다.
#
# - 동적 계획 알고리즘은 먼저 입력 크기가 작은 부분 문제들을 모두 해결한 후에 그 해들을 이용하여 보다 큰 크기의 부분 문제들을 해결하여 최종적으로 원래
# 주어진 입력의 문제를 해결하는 알고리즘이다.

# %%
"""
V E
v1 w1 v2 w2...
7 8
1 2 1 3 2 4 2 5 4 6 5 6 6 7 3 7
"""
def dfs(n, V, adj_m):
    # stack 생성
    stack = []
     # visited 생성
    visited = [0] * (V+1)
    # 시작점 방문 표시
    visited[n] = 1
    # do[n]
    print(n)
    while True:
        for w in range(1, V):   # 현재 정점 n에 인접하고 미방문 w 찾기
            if adj_m[n][w] == 1 and visited[w] == 0:
                
                stack.append(n) # push(v), v = w
                n = w
                print(n)  # do ()
                visited[n] = 1  # w 방문표시
                break  # for w, n 에 인접인 w 찾은경우
        else:
            if stack: # 스텍에 지나온 정점이 남아있으면 
                n = stack.pop()  # pop() 해서 다시 다른 w 찾기
            else:
                break  # while True 탐색 끝

    return
V, E = map(int, input().split()) # 1번부터 V번 정점
arr = list(map(int, input().split()))
adj_m = [[0]*(V+1) for _ in range(V+1)]
for i in range(E):
    v1, v2 = arr[i*2], arr[i*2+1]
    adj_m[v1][v2] = 1
    adj_m[v2][v1] = 1

dfs(1, V)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       1 """
#       2 V E
#       3 v1 w1 v2 w2...
#       4 7 8
#       5 1 2 1 3 2 4 2 5 4 6 5 6 6 7 3 7
#       6 """
# ----> 7 V, E = map(int, input().split()) # 1번부터 V번 정점
#       8 arr = list(map(int, input().split()))
#       9 adj_m = [[0]*(V+1) for _ in range(V+1)]
#
# ValueError: invalid literal for int() with base 10: 'V'
