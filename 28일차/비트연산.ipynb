# %%
# 엔디안 확인방법
import sys
print(sys.byteorder)
# Out:
# little

# %% [markdown]
# # 진수의 음수
#
# - 2의 보수 : 1의 보수방법으로 표현된 값의 최하위 비트에 1을 더한다.
#
#
# # 진수의 실수 표현
# - 진수의 실수표현은 소숫점을 저장하는 과정에서 오차가 생길수 있다.(컴퓨터는 실수를 근사적으로 표현한다.)
