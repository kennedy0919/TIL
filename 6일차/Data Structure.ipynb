# %% [markdown]
# # 데이터 구조 활용
# - 문자열, 리스트, 딕셔너리 등 각 데이터 구조의 메서드를 호출하여 다양한 기능을 활용하기
#
# # 메서드
# - 객체에 속한 함수
#     - 객체의 상태를 조작하거나 동작을 수행
#
# ### split, join 매서드는 꼭 알아두기!!!!!!!!!
#
# ### 매서드는 이어서 사용 가능
#
# # 리스트 값 추가 및 삭제 메서드
# 1. .append
#     - 리스트 마지막에 항복 추가
#
# 2. extend(iterable)
#     - 리스트에 다른 반복 가능한 객체의 모든 항목을 추가

# %%
## append 와 extend 차이

numbers = [1, 2, 3]
numbers2 = [4, 5, 6]
numbers.append(numbers2)
print(numbers)

numbers.extend(numbers)
print(numbers)
# Out:
# [1, 2, 3, [4, 5, 6]]
# [1, 2, 3, [4, 5, 6], 1, 2, 3, [4, 5, 6]]

# %% [markdown]
# ### .pop
# - 리스트에서 지정한 인덱스의 항목을 제거하고 반환
# - 작성하지 않을 경우 마지막 항목을 제거

# %%
numbers = [1, 2, 3]
# sort 메서드
print(numbers.sort())   # None

numbers = [3, 2, 1]
# sorted 함수
print(sorted(numbers))  # [1, 2, 3]
print(numbers)  # [3, 2, 1]
# Out:
# None
# [1, 2, 3]
# [3, 2, 1]

# %%
#### quize

numbers = [1, 2, 3]

# 1. 할당
list1 = numbers

# 2. 슬라이싱
list2 = numbers[:]

numbers[0] = 100
print(list1)  ## [100, 2, 3]
print(list2)  ## [1, 2, 3]

# %% [markdown]
# ### split, join 매서드는 꼭 알아두기!!!!!!!!!
# ### append extend pop
# ### L.reverse(), L.sort()

# %%
dic = {"c" : 3, "b" : 10, "a" : 5}

print(sorted(dic))
# ex) 딕셔너리를 정렬하고 싶은데 키가 아니라 값을 기준으로 정렬하고 싶다.
# "c" : 3, "a" : 5, "b" : 10
# sorted(dic, key=)    # key 인자는 정렬방법을 서술할 함수


def sort_key(item):

    # 정렬 기준을 return
    print(item)
    return(item[1])

# sorted(dic.items(), key=sort_key)   # key 인자는 정렬방법을 서술할 함수

print(sorted(dic.items(), key=lambda item : item[1]))
# Out:
# ['a', 'b', 'c']
# [('c', 3), ('a', 5), ('b', 10)]

# %%
## .find(x)
## x 의 첫번째 위치를 반환
## x 가 없으면 -1 반환
print("banana".find("n"))
print("banana".find("z"))
# Out:
# 2
# -1

# %%
## .index(x)
## x의 첫번째 위치를 반환, 없으면 오류 발생
print("banana".index("n"))
print("banana".index("z"))

# %%
## .isupper(x) / .islower(x)
## 문자열이 모두 대문자/소문자로 이루어져 있는지 확인
string1 = "HELLO"
string2 = "Hello"
print(string1.isupper())
print(string1.lower())
print(string2.isupper())
print(string2.lower())

# %%
## .isalpha(x)
## 문자열이 알파벳으로만 이루어져 있는지 확인

string1 = "Hello"
string2 = "123"
print(string1.isalpha())
print(string2.isalpha())
